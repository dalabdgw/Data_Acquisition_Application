# %% [markdown]
#  # ffmpeg로 비디오 자르기
#
# Input : 원하는 SEC
# OUTPUT : 동영상 FIle

# %%
# !ffmpeg -i video.mp4 -ss 00:00:10 -to 00:00:20 -c copy output.mp4
# Out:
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'output.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  281 fps=0.0 q=-1.0 Lsize=     131kB time=00:00:09.96 bitrate= 107.8kbits/s speed=2.16e+03x
# video:65kB audio:58kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.363320%

# %%
time_data = "../phrase (2)/phrase data.txt"
file_name = "video.mp4"

f = open(time_data, 'r')
line = f.readlines()


time_list = []
time_list.append('0:00')

for i in range(len(line[0].split(' '))):
    time_list.append(line[0].split(' ')[i])
    
#!ffmpeg -i {file_name} -ss {start_time} -to {end_time} -c copy output1.mp4
for i in range(len(time_list)-1):
    data_name = "data" + str(i) + ".mp4"
    start_time = time_list[i]
    end_time = time_list[i+1]
    print(start_time, end_time)
    # !ffmpeg -i {file_name} -ss {start_time} -to {end_time} -c copy {data_name}
# Out:
# 0:00 0:07
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data0.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   51 fps=0.0 q=-1.0 Lsize=      68kB time=00:00:06.96 bitrate=  80.3kbits/s speed=3.54e+03x
# video:24kB audio:42kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.709988%
# 0:07 0:12
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data1.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   41 fps=0.0 q=-1.0 Lsize=      54kB time=00:00:04.98 bitrate=  88.6kbits/s speed=1.53e+03x
# video:22kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.427867%
# 0:12 0:18
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data2.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   61 fps=0.0 q=-1.0 Lsize=      72kB time=00:00:05.97 bitrate=  99.0kbits/s speed=1.36e+03x
# video:34kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.623926%
# 0:18 0:23
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data3.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   51 fps=0.0 q=-1.0 Lsize=      54kB time=00:00:04.98 bitrate=  89.2kbits/s speed= 745x
# video:22kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.642341%
# 0:23 0:29
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data4.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   71 fps=0.0 q=-1.0 Lsize=      61kB time=00:00:05.97 bitrate=  84.1kbits/s speed= 752x
# video:23kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.963782%
# 0:29 0:34
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data5.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   61 fps=0.0 q=-1.0 Lsize=      56kB time=00:00:04.99 bitrate=  91.2kbits/s speed= 542x
# video:23kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.925581%
# 0:34 0:40
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data6.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   81 fps=0.0 q=-1.0 Lsize=      62kB time=00:00:05.98 bitrate=  84.2kbits/s speed= 585x
# video:23kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.160403%
# 0:40 0:45
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data7.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   71 fps=0.0 q=-1.0 Lsize=      55kB time=00:00:04.96 bitrate=  90.3kbits/s speed= 418x
# video:22kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.516038%
# 0:45 0:51
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data8.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   91 fps=0.0 q=-1.0 Lsize=      73kB time=00:00:05.99 bitrate=  99.7kbits/s speed= 389x
# video:34kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.392475%
# 0:51 0:56
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data9.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=   81 fps=0.0 q=-1.0 Lsize=      56kB time=00:00:04.96 bitrate=  92.0kbits/s speed= 311x
# video:23kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.828091%
# 0:56 1:02
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data10.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  101 fps=0.0 q=-1.0 Lsize=      62kB time=00:00:05.99 bitrate=  84.6kbits/s speed= 336x
# video:23kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.791049%
# 1:02 1:08
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data11.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  121 fps=0.0 q=-1.0 Lsize=      62kB time=00:00:05.98 bitrate=  84.9kbits/s speed= 327x
# video:22kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.750191%
# 1:08 1:13
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data12.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  111 fps=0.0 q=-1.0 Lsize=      78kB time=00:00:04.96 bitrate= 129.4kbits/s speed= 243x
# video:45kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.413102%
# 1:13 1:19
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data13.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  131 fps=0.0 q=-1.0 Lsize=      63kB time=00:00:05.99 bitrate=  86.0kbits/s speed= 281x
# video:23kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.996181%
# 1:19 1:24
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data14.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  121 fps=0.0 q=-1.0 Lsize=      65kB time=00:00:04.96 bitrate= 106.4kbits/s speed= 223x
# video:31kB audio:29kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.968275%
# 1:24 1:30
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data15.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  141 fps=0.0 q=-1.0 Lsize=      64kB time=00:00:05.96 bitrate=  87.8kbits/s speed= 233x
# video:24kB audio:35kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 8.210916%
# 1:30 1:38
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data16.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  221 fps=0.0 q=-1.0 Lsize=     124kB time=00:00:07.98 bitrate= 126.8kbits/s speed= 307x
# video:70kB audio:47kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.482157%
# 1:38 1:46
# ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-11-09T06:18:31.000000Z
#   Duration: 00:01:55.68, start: 0.000000, bitrate: 114 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'data17.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf60.3.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], q=2-31, 64 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       creation_time   : 2019-11-09T06:18:31.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 11/08/2019.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=  141 fps=0.0 q=-1.0 Lsize=      99kB time=00:00:07.97 bitrate= 102.2kbits/s speed= 273x
# video:48kB audio:47kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.122782%

# %%
time_data = "../phrase (2)/phrase data.txt"
f = open(time_data, 'r')
line = f.readlines()

time = []
time.append('0:00')
for i in range(len(line[0].split(' '))):
    time.append(line[0].split(' ')[i])
print(time)
# Out:
# ['0:00', '0:07', '0:12', '0:18', '0:23', '0:29', '0:34', '0:40', '0:45', '0:51', '0:56', '1:02', '1:08', '1:13', '1:19', '1:24', '1:30', '1:38', '1:46']
# 0:00 0:07
# 0:07 0:12
# 0:12 0:18
# 0:18 0:23
# 0:23 0:29
# 0:29 0:34
# 0:34 0:40
# 0:40 0:45
# 0:45 0:51
# 0:51 0:56
# 0:56 1:02
# 1:02 1:08
# 1:08 1:13
# 1:13 1:19
# 1:19 1:24
# 1:24 1:30
# 1:30 1:38
# 1:38 1:46
